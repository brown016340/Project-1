# %%
# Dependencies and Setup
import pandas as pd
import requests
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from pprint import pprint

# Import API key
from config import geoapify_key

# %%
squirrels_df = pd.read_csv("Resources\\2018_Central_Park_Squirrel_Census_-_Squirrel_Data.csv")
squirrels_df.head()
# Out:
#            X          Y Unique Squirrel ID Hectare Shift      Date  \
# 0 -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1 -73.968857  40.783783     21B-AM-1019-04     21B    AM  10192018
# 2 -73.974281  40.775534     11B-PM-1014-08     11B    PM  10142018
# 3 -73.959641  40.790313     32E-PM-1017-14     32E    PM  10172018
# 4 -73.970268  40.776213     13E-AM-1017-05     13E    AM  10172018
#
#    Hectare Squirrel Number    Age Primary Fur Color Highlight Fur Color  ...  \
# 0                        3    NaN               NaN                 NaN  ...
# 1                        4    NaN               NaN                 NaN  ...
# 2                        8    NaN              Gray                 NaN  ...
# 3                       14  Adult              Gray                 NaN  ...
# 4                        5  Adult              Gray            Cinnamon  ...
#
#     Kuks  Quaas  Moans Tail flags Tail twitches  Approaches  Indifferent  \
# ...

# %%
# Lets get a total for the number of times a given behavior is exhibited and not exhibited
squirrels_df["Approaches"].value_counts()
# Out:
# Approaches
# False    2845
# True      178
# Name: count, dtype: int64

# %%
# Narrow down DF to rows where a given behavior is True
# In this case, lets narrow it to where Approaches is True
approaches = squirrels_df[squirrels_df["Approaches"] == True]

# Reset Index
approaches = approaches.reset_index(drop=True)

approaches
# Out:
#              X          Y Unique Squirrel ID Hectare Shift      Date  \
# 0   -73.957956  40.795934     38C-PM-1014-09     38C    PM  10142018
# 1   -73.958497  40.798289     40B-AM-1019-03     40B    AM  10192018
# 2   -73.974563  40.769260      5E-AM-1008-06     05E    AM  10082018
# 3   -73.961071  40.791483     32D-AM-1013-06     32D    AM  10132018
# 4   -73.952868  40.792581     36I-PM-1007-13     36I    PM  10072018
# ..         ...        ...                ...     ...   ...       ...
# 173 -73.974731  40.765389      1G-PM-1010-03     01G    PM  10102018
# 174 -73.976739  40.768932      4D-PM-1008-10     04D    PM  10082018
# 175 -73.972408  40.774416     11D-AM-1010-08     11D    AM  10102018
# 176 -73.975208  40.775538     11B-AM-1007-01     11B    AM  10072018
# 177 -73.975479  40.769640      5E-PM-1012-01     05E    PM  10122018
#
#      Hectare Squirrel Number       Age Primary Fur Color Highlight Fur Color  \
# ...

# %%
# What is the breakdown of the number of squirrels with each fur color that approached?
approaches_df = pd.DataFrame(approaches["Primary Fur Color"].value_counts())
approaches_df
# Out:
#                    count
# Primary Fur Color
# Gray                 126
# Cinnamon              44
# Black                  6

# %%
# Lets make a pie chart for the ones that approach, breaking it down by color
plt.pie(approaches_df["count"])











# labels = approaches["Primary Fur Color"]
# explode = (0.1, 0, 0)

# plt.pie(approaches["Primary Fur Color"], explode=explode, values=approaches["Primary Fur Color"].value_counts())

plt.show()

# %%
# Make the map

# %%
# Plot the points for where Approaches is true
