# %%
import pandas as pd
import requests
import io
import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
 # Downloading the csv file from GitHub 

url = "https://raw.githubusercontent.com/brown016340/Project-1/development/Resources/2018_Squirrel_Data.csv" # Make sure the url is the raw version of the file on GitHub
download = requests.get(url).content

# Reading the downloaded content and turning it into a pandas dataframe

squirrel_df = pd.read_csv(io.StringIO(download.decode('utf-8')))

# Printing out the first 5 rows of the dataframe

squirrel_df.head()
# Out:
#            X          Y Unique Squirrel ID Hectare Shift      Date  \
# 0 -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1 -73.968857  40.783783     21B-AM-1019-04     21B    AM  10192018
# 2 -73.974281  40.775534     11B-PM-1014-08     11B    PM  10142018
# 3 -73.959641  40.790313     32E-PM-1017-14     32E    PM  10172018
# 4 -73.970268  40.776213     13E-AM-1017-05     13E    AM  10172018
#
#    Hectare Squirrel Number    Age Primary Fur Color Highlight Fur Color  ...  \
# 0                        3    NaN               NaN                 NaN  ...
# 1                        4    NaN               NaN                 NaN  ...
# 2                        8    NaN              Gray                 NaN  ...
# 3                       14  Adult              Gray                 NaN  ...
# 4                        5  Adult              Gray            Cinnamon  ...
#
#     Kuks  Quaas  Moans Tail flags Tail twitches  Approaches  Indifferent  \
# 0  False  False  False      False         False       False        False
# 1  False  False  False      False         False       False        False
# 2  False  False  False      False         False       False        False
# 3  False  False  False      False         False       False        False
# 4  False  False  False      False         False       False        False
#
#    Runs from  Other Interactions                                    Lat/Long
# 0      False                 NaN  POINT (-73.9561344937861 40.7940823884086)
# 1      False                 NaN  POINT (-73.9688574691102 40.7837825208444)
# 2      False                 NaN  POINT (-73.97428114848522 40.775533619083)
# 3       True                 NaN  POINT (-73.9596413903948 40.7903128889029)
# 4      False                 NaN  POINT (-73.9702676472613 40.7762126854894)
#
# [5 rows x 31 columns]

# %%
colors = squirrel_df.groupby("Primary Fur Color")
total_colors = colors["Primary Fur Color"].count()
total_colors.head()
# Out:
# Primary Fur Color
# Black        103
# Cinnamon     392
# Gray        2473
# Name: Primary Fur Color, dtype: int64

# %%
chasing_df = squirrel_df[squirrel_df["Chasing"] == True]
climbing_df = squirrel_df[squirrel_df["Climbing"] == True]
eating_df = squirrel_df[squirrel_df["Eating"] == True]
foraging_df = squirrel_df[squirrel_df["Foraging"] == True]

chasing_df.head()
# Out:
#             X          Y Unique Squirrel ID Hectare Shift      Date  \
# 2  -73.974281  40.775534     11B-PM-1014-08     11B    PM  10142018
# 14 -73.970611  40.769812      7H-AM-1006-05     07H    AM  10062018
# 22 -73.958737  40.790852     32F-PM-1008-07     32F    PM  10082018
# 32 -73.974207  40.775796     12B-AM-1007-01     12B    AM  10072018
# 39 -73.970253  40.770600      8H-AM-1017-06     08H    AM  10172018
#
#     Hectare Squirrel Number    Age Primary Fur Color Highlight Fur Color  ...  \
# 2                         8    NaN              Gray                 NaN  ...
# 14                        5  Adult              Gray            Cinnamon  ...
# 22                        7  Adult              Gray                 NaN  ...
# 32                        1  Adult              Gray            Cinnamon  ...
# 39                        6  Adult              Gray            Cinnamon  ...
#
#      Kuks  Quaas  Moans Tail flags Tail twitches  Approaches  Indifferent  \
# 2   False  False  False      False         False       False        False
# 14  False  False  False      False         False       False         True
# 22  False  False  False      False         False       False         True
# 32  False  False  False       True         False       False         True
# 39  False  False  False      False         False       False         True
#
#     Runs from  Other Interactions                                    Lat/Long
# 2       False                 NaN  POINT (-73.97428114848522 40.775533619083)
# 14      False                 NaN  POINT (-73.9706105896967 40.7698124821507)
# 22      False                 NaN   POINT (-73.958736593111 40.7908524370626)
# 32      False                 NaN  POINT (-73.9742073452913 40.7757957380463)
# 39      False                 NaN  POINT (-73.970252675331 40.77059995882221)
#
# [5 rows x 31 columns]

# %%
foraging_map = foraging_df.hvplot.points(
    "X",
    "Y",
    geo = True,
    tiles = "ESRI",
    height=450,
    width=600,
    legend = False,
    size = 30,
    alpha = .25,
    color = "green",
    title = "Foraging Locations"
)
foraging_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [X,Y]

# %%
eating_map = eating_df.hvplot.points(
    "X",
    "Y",
    geo = True,
    tiles = "ESRI",
    height=450,
    width=600,
    legend = False,
    size = 30,
    alpha = .25,
    color = "purple",
    title = "Eating Locations"
)
eating_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [X,Y]

# %%
climbing_map = climbing_df.hvplot.points(
    "X",
    "Y",
    geo = True,
    tiles = "ESRI",
    height=450,
    width=600,
    legend = False,
    size = 30,
    alpha = .25,
    color = "r",
    title = "Climbing Locations"
)
climbing_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [X,Y]

# %%
chasing_map = chasing_df.hvplot.points(
    "X",
    "Y",
    geo = True,
    tiles = "ESRI",
    height=450,
    width=600,
    legend = False,
    size = 30,
    alpha = .25,
    title = "Chasing Locations"

)
chasing_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [X,Y]

# %%
combined_map = (chasing_map + climbing_map + foraging_map + eating_map)


# Display the combined map
combined_map
# Out:
# :Layout
#    .Overlay.I   :Overlay
#       .WMTS.I   :WMTS   [Longitude,Latitude]
#       .Points.I :Points   [X,Y]
#    .Overlay.II  :Overlay
#       .WMTS.I   :WMTS   [Longitude,Latitude]
#       .Points.I :Points   [X,Y]
#    .Overlay.III :Overlay
#       .WMTS.I   :WMTS   [Longitude,Latitude]
#       .Points.I :Points   [X,Y]
#    .Overlay.IV  :Overlay
#       .WMTS.I   :WMTS   [Longitude,Latitude]
#       .Points.I :Points   [X,Y]

# %%
hvplot.save(eating_map, 'eating.png')
